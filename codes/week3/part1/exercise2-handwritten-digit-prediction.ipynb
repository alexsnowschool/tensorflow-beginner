# %% [markdown]
# ## Hand Written Digit Prediction

# %% [markdown]
# ဒီ exercise မှာကတော့ လူတွေရေးထားတဲ့ hand written digit photo တွေကိုကြည့်ပြီး ဘယ် photo က ဘယ် digit လဲဆိုတာကို prediction လုပ်သွားမှာဖြစ်ပါတယ်။
#
#
# *   MNIST Dataset ကို train ထားတဲ့ model ရဲ့ accuracy 99% or above ရအောင် train မယ် fixed number of epoch မထားပဲ။
# *   ပြီးရင် လိုချင်တဲ့ accuracy ရောက်ရင် training ကိုရပ်မယ်။
#
# Some notes:
# 1. It should succeed in less than 10 epochs, so it is okay to change epochs= to 10, but nothing larger
# 2. When it reaches 99% or greater it should print out the string "Reached 99% accuracy so cancelling training!"
# 3. If you add any additional variables, make sure you use the same names as the ones used in the class

# %%
import tensorflow as tf

# %%
def train_mnist():
   
    mnist = tf.keras.datasets.mnist
    (x_train, y_train),(x_test, y_test) = mnist.load_data(path=path)
    model = tf.keras.models.Sequential([
     
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    # model fitting
    history = model.fit(
         
    )
    # model fitting
    return history.epoch, history.history['acc'][-1]

# %%
train_mnist()

# %%
# %%javascript
# <!-- Save the notebook -->
# IPython.notebook.save_checkpoint();

# %%
# %%javascript
# IPython.notebook.session.delete();
# window.onbeforeunload = null
# setTimeout(function() { window.close(); }, 1000);
