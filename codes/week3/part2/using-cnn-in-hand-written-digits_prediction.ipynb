# %% [markdown]
# <figure>
# <center>
# <img src='https://raw.githubusercontent.com/alexsnowschool/TensorFlow-Beginner/main/project_img.png' width = '800px'/>
# </center>
# </figure>

# %% [markdown]
# ## Hand Written Digits Prediction Using CNN
#
# **ဒီ Exercise မှာကတော့ handwritten digit prediction လုပ်တဲ့နေရာမှာ Convolutional Neural Network Architecture ကိုသုံးပြီး prediction လုပ်သွားမှာဖြစ်ပါတယ်။**
#
# Notes:
#
#
# *   Single Convolutional Layer and MaxPooling2D ကိုသုံးမယ်။
# *   Accuracy 99.8% ရောက်ရင် trainning ကိုရပ်မယ်။ 99.8% accuracy ရောက်ရင် "Reached 99.8% accuracy so cancelling training" လို့ print ထုတ်မယ်။

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy') >= 0.998):
      print("\nReached 99.8% accuracy so cancelling training!")
      self.model.stop_training = True

# %%
callbacks = myCallback()
(training_images, training_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

training_images = training_images.reshape(60000, 28, 28, 1)
training_images = training_images / 255.0

test_images = test_images.reshape(10000, 28, 28, 1)
test_images = test_images / 255.0


model = Sequential([
        Conv2D(64, (3, 3), activation = 'relu', input_shape = (28, 28, 1)),
        MaxPooling2D(2, 2),
        Flatten(),
        Dense(128, activation = 'relu'),
        Dense(10, activation = 'softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# model fitting
history = model.fit(
    training_images, training_labels, epochs = 18, callbacks = [callbacks]
)
# Out:
# Epoch 1/18
# 1875/1875 [==============================] - 56s 30ms/step - loss: 0.1386 - accuracy: 0.9585
# Epoch 2/18
# 1875/1875 [==============================] - 56s 30ms/step - loss: 0.0492 - accuracy: 0.9855
# Epoch 3/18
# 1875/1875 [==============================] - 56s 30ms/step - loss: 0.0318 - accuracy: 0.9900
# Epoch 4/18
# 1875/1875 [==============================] - 55s 30ms/step - loss: 0.0196 - accuracy: 0.9934
# Epoch 5/18
# 1875/1875 [==============================] - 56s 30ms/step - loss: 0.0134 - accuracy: 0.9958
# Epoch 6/18
# 1875/1875 [==============================] - 58s 31ms/step - loss: 0.0108 - accuracy: 0.9964
# Epoch 7/18
# 1875/1875 [==============================] - 57s 30ms/step - loss: 0.0071 - accuracy: 0.9975
# Epoch 8/18
# 1875/1875 [==============================] - 56s 30ms/step - loss: 0.0071 - accuracy: 0.9977
# Epoch 9/18
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9984
# ...

# %%
print("Total Epoch:", history.epoch)
print("Final Accuracy: ", history.history['accuracy'][-1])
# Out:
# Total Epoch: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Final Accuracy:  0.9984166622161865
